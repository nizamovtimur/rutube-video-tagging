# %%
import requests
import time
import numpy as np
import pandas as pd

# %%
times = list()
ious = list()

# %%
df = pd.read_csv('x_test.csv', sep=',')[["title", "description"]]
for index, row in df.iterrows():
    start = time.time()
    response = requests.post("url", json=data)
    end = time.time()
    data = response.json()
    times.append(end - start)
# Out:
# Салют, Начальник | 4 серия
# Сколько Стоит Тачка: Галина Ржаксенская - от подаренных прав до холостяка
# Какова Меркурия? | Выпуск 12
# Смехмашина | Выпуск 13
# Абьюз-шоу | Выпуск № 9 часть 1 | Ирина Барышева
# Домашняя кухня от шефа: Выпуск №15
# СarJitsu. 3 сезон, 2 серия. Ушу Мастер vs Максим Намитов
# Прогулка по стране - Нижний Новгород
# Смехмашина | Выпуск 7
# МАКСИМ НАРОДНЫЙ Выпуск №38 БОРЩ ИЛИ ЩИ? ВОТ В ЧЕМ ВОПРОС
# Punch Box. 2 сезон, 5 серия. Курд vs Савинов Иван
# Пикап Прокачка | Выпуск 2
# PykoJob | Выпуск 15 | Море в гостиной
# Роман Юнусов и ЗОЯ из «Ленинград» выясняют, чья палка бьёт сильнее
# Балтийская миля 2022
# МАКСИМ НАРОДНЫЙ Выпуск №36 ПОЖАРИЛ ВАРЕНЫЕ ЯЙЦА, ПОЛУЧИЛОСЬ ОЧЕНЬ ВКУСНО
# Стендап гороскоп: Юлия Демиденкова про Козерогов
# Команда "РК-Спорт" в ГрандТуре-2022: Моя "Байкальская миля"
# Люди у которых клюет I # 2I Рыбалка в Турции
# DSC OFF на Байкальской миле 2020
# СarJitsu. 3 сезон, 7 серия. Джанго vs Кунг-фу Панда
# ...
